# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline
from tensorflow import keras
from prophet import Prophet
import itertools
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
path = '/content/drive/MyDrive/01_ITE/Projects/Data_Science/datasets/'
cumtd_data = '00CUMTD_Route_Ridership_By_Day_September_2022_2023.csv'
data_file = path + cumtd_data # get the directory of the file
# Out:
# Mounted at /content/drive

# %%
# df1: Dataframe for monthly data
df1 = pd.read_csv(data_file) # read in the csv file
#df1['Date'] = pd.to_datetime(df1['Date'],utc=True)
#df1['Date'] = pd.to_datetime(df1['Date']).dt.date
#df1['Date'] = pd.to_datetime(df1.Date, format='%Y-%m-%d')
#df1['Day of Week'] = df1['Date'].dt.dayofweek
df1
# Out:
#                             Date                        Line In (Sum)  \
# 0      2022-08-31T19:00:00-05:00                1 YELLOW ALT       34
# 1      2022-08-31T19:00:00-05:00                10W GOLD ALT       47
# 2      2022-08-31T19:00:00-05:00               1N YELLOW ALT      140
# 3      2022-08-31T19:00:00-05:00            1N YELLOW ALT PM       41
# 4      2022-08-31T19:00:00-05:00               1S YELLOW ALT      120
# ...                          ...                         ...      ...
# 15774  2023-09-29T19:00:00-05:00    TEAL LATE NIGHT SATURDAY      163
# 15775  2023-09-29T19:00:00-05:00               TEAL SATURDAY    1,980
# 15776  2023-09-29T19:00:00-05:00     YELLOW EVENING SATURDAY      868
# 15777  2023-09-29T19:00:00-05:00  YELLOW LATE NIGHT SATURDAY       79
# 15778  2023-09-29T19:00:00-05:00             YELLOW SATURDAY    2,109
#
#       Out (Sum)  Load (Avg.)  Load max  #APC-Trips
# 0            34          8.1        33           2
# 1            47         14.6        43           1
# 2           140         24.0        87           2
# 3            41         15.5        41           1
# 4           120          8.2        56           3
# ...         ...          ...       ...         ...
# 15774       163          3.2        21          16
# 15775     1,980          9.0        53          74
# 15776       868          6.0        79          26
# 15777        79          0.7        13          21
# 15778     2,109          9.8        51          43
#
# [15779 rows x 7 columns]

# %%
silverDF = pd.DataFrame(df1.groupby('Line').get_group('SILVER').reset_index()).drop('index', axis = 1)
load_max_per_day = silverDF.groupby('Date')['Load max'].mean().reset_index()
avg_load_per_day = silverDF.groupby('Date')['Load (Avg.)'].mean().reset_index()

plt.figure(figsize=(15,7))
plt.plot(load_max_per_day['Date'], load_max_per_day['Load max'], marker='o', linestyle='-',color='blue',label='load max')
plt.plot(avg_load_per_day['Date'], avg_load_per_day['Load (Avg.)'], marker='o', linestyle='-',color='red',label='load average')
plt.title('21 silver Load Max & Average Load Over Day')
plt.xlabel('Date')
plt.ylabel('Load (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.grid(True)
plt.savefig('Load_Max_Load_Average_Over_Time silver.png')
plt.show()

# %%
columns_to_traverse = df1.keys()[2:] # these are the columns we will be traversing for out data analysis
columns_to_traverse
# Out:
# Index(['In (Sum)', 'Out (Sum)', 'Load (Avg.)', 'Load max', '#APC-Trips'], dtype='object')

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1
# Out:
# /tmp/ipython-input-7-1017232124.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df1['Date'] = pd.to_datetime(df1['Date'])
#                             Date                        Line In (Sum)  \
# 0      2022-08-31 19:00:00-05:00                1 YELLOW ALT       34
# 1      2022-08-31 19:00:00-05:00                10W GOLD ALT       47
# 2      2022-08-31 19:00:00-05:00               1N YELLOW ALT      140
# 3      2022-08-31 19:00:00-05:00            1N YELLOW ALT PM       41
# 4      2022-08-31 19:00:00-05:00               1S YELLOW ALT      120
# ...                          ...                         ...      ...
# 15774  2023-09-29 19:00:00-05:00    TEAL LATE NIGHT SATURDAY      163
# 15775  2023-09-29 19:00:00-05:00               TEAL SATURDAY    1,980
# 15776  2023-09-29 19:00:00-05:00     YELLOW EVENING SATURDAY      868
# 15777  2023-09-29 19:00:00-05:00  YELLOW LATE NIGHT SATURDAY       79
# 15778  2023-09-29 19:00:00-05:00             YELLOW SATURDAY    2,109
#
#       Out (Sum)  Load (Avg.)  Load max  #APC-Trips
# 0            34          8.1        33           2
# 1            47         14.6        43           1
# 2           140         24.0        87           2
# 3            41         15.5        41           1
# 4           120          8.2        56           3
# ...         ...          ...       ...         ...
# 15774       163          3.2        21          16
# 15775     1,980          9.0        53          74
# 15776       868          6.0        79          26
# 15777        79          0.7        13          21
# 15778     2,109          9.8        51          43
#
# [15779 rows x 7 columns]

# %%
bus_lines = df1['Line'].unique() # we want to see how many unique bus lines there are
print(f'CUMTD bus lines: {bus_lines}')
# Out:
# CUMTD bus lines: ['1 YELLOW ALT' '10W GOLD ALT' '1N YELLOW ALT' '1N YELLOW ALT PM'
#  '1S YELLOW ALT' '3S LAVENDER ALT' '5E GREEN EXPRESS 1 ALT'
#  '5E GREEN EXPRESS ALT' '5W GREEN ALT 2' '5W GREEN EXPRESS 2'
#  '7E GREY ALT' '7W GREY ALT' 'BLUE' 'BRONZE' 'BRONZE ALT' 'BROWN'
#  'BROWN ALT' 'BROWN ALT PM' 'BROWN ALT1' 'GOLD' 'GOLD ALT' 'GOLDHOPPER'
#  'GREEN' 'GREEN ALT' 'GREEN EVENING' 'GREEN EXPRESS' 'GREEN EXPRESS ALT'
#  'GREEN LATE NIGHT' 'GREENHOPPER' 'GREENHOPPER EVENING' 'GREY' 'GREY ALT'
#  'GREY EVENING' 'ILLINI' 'ILLINI EVENING' 'LAVENDER' 'LAVENDER ALT'
#  'LIME EVENING' 'LINK' 'NAVY' 'ORANGE' 'ORANGE ALT' 'ORANGEHOPPER' 'PINK'
#  'PINK ALT' 'RAVEN' 'RED' 'RUBY' 'RUBY EVENING' 'SILVER' 'SILVER EVENING'
#  'SILVER LATE NIGHT' 'TEAL' 'TEAL EVENING' 'TEAL LATE NIGHT' 'YELLOW'
#  'YELLOW EVENING' 'YELLOW LATE NIGHT' 'YELLOWHOPPER'
#  'GREEN EVENING SATURDAY' 'GREEN LATE NIGHT SATURDAY' 'GREEN SATURDAY'
#  'GREENHOPPER EVENING SATURDAY' 'GREY EVENING SATURDAY' 'GREY SATURDAY'
#  'ILLINI EVENING SATURDAY' 'ILLINI LIMITED SATURDAY' 'LAVENDER SATURDAY'
#  'LIME EVENING SATURDAY' 'LIME SATURDAY' 'RED SATURDAY'
#  'RUBY EVENING SATURDAY' 'RUBY SATURDAY' 'SILVER EVENING SATURDAY'
#  'SILVER SATURDAY' 'TEAL EVENING SATURDAY' 'TEAL LATE NIGHT SATURDAY'
#  'TEAL SATURDAY' 'YELLOW EVENING SATURDAY' 'YELLOW LATE NIGHT SATURDAY'
#  'YELLOW SATURDAY' 'GREEN LATE NIGHT SUNDAY' 'GREEN SUNDAY' 'GREY SUNDAY'
#  'ILLINI EVENING SUNDAY' 'ILLINI LIMITED SUNDAY' 'LAVENDER SUNDAY'
#  'LIME SUNDAY' 'RUBY SUNDAY' 'SILVER EVENING SUNDAY' 'SILVER SUNDAY'
#  'TEAL LATE NIGHT SUNDAY' 'TEAL SUNDAY' 'YELLOW LATE NIGHT SUNDAY'
#  'YELLOW SUNDAY' 'TRANSPORT' 'TRANSPORT - CHAMPAIGN'
#  'MAINTENANCE TEST ROUTE' 'ILLINI LIMITED EVENING SATURDAY'
#  'SILVER LIMITED EVENING SATURDAY' 'SILVER LIMITED SATURDAY'
#  'SILVER LIMITED SUNDAY' 'ILLINI LIMITED' 'ILLINI LIMITED EVENING'
#  'SILVER LIMITED EVENING' 'TEST ORANGE' 'TEST BRONZE' 'TEST TEAL']

# %%
silverLine = [line for line in bus_lines if "silver" in line.lower()]
silverLine
# Out:
# ['SILVER',
#  'SILVER EVENING',
#  'SILVER LATE NIGHT',
#  'SILVER EVENING SATURDAY',
#  'SILVER SATURDAY',
#  'SILVER EVENING SUNDAY',
#  'SILVER SUNDAY',
#  'SILVER LIMITED EVENING SATURDAY',
#  'SILVER LIMITED SATURDAY',
#  'SILVER LIMITED SUNDAY',
#  'SILVER LIMITED EVENING']

# %%
# Define the list of line names you're interested in
lines_of_interest = silverLine

# Filter the dataframe based on the list
filtered_dataframe = df1[df1['Line'].isin(lines_of_interest)]
filtered_dataframe
# Out:
#                             Date                     Line In (Sum) Out (Sum)  \
# 49     2022-08-31 19:00:00-05:00                   SILVER    3,035     3,035
# 50     2022-08-31 19:00:00-05:00           SILVER EVENING      197       197
# 51     2022-08-31 19:00:00-05:00        SILVER LATE NIGHT       30        30
# 108    2022-09-01 19:00:00-05:00                   SILVER    2,533     2,533
# 109    2022-09-01 19:00:00-05:00           SILVER EVENING      235       235
# ...                          ...                      ...      ...       ...
# 15747  2023-09-28 19:00:00-05:00                   SILVER    2,818     2,818
# 15748  2023-09-28 19:00:00-05:00           SILVER EVENING      448       448
# 15749  2023-09-28 19:00:00-05:00        SILVER LATE NIGHT      138       138
# 15771  2023-09-29 19:00:00-05:00  SILVER EVENING SATURDAY      688       688
# 15772  2023-09-29 19:00:00-05:00          SILVER SATURDAY    1,590     1,590
#
#        Load (Avg.)  Load max  #APC-Trips
# 49            12.6        75          93
# 50             4.2        18          15
# 51             1.0         9           9
# 108           10.1        87          92
# 109            4.6        22          17
# ...            ...       ...         ...
# 15747         11.6        69          92
# 15748         10.1        45          15
# 15749          3.6        33          16
# 15771          4.7        38          58
# 15772          9.9        85          60
#
# [931 rows x 7 columns]

# %%
for key in columns_to_traverse:
    filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
    filtered_dataframe[key] = filtered_dataframe[key].astype('float64')
# Out:
# /tmp/ipython-input-11-2574090907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
# /tmp/ipython-input-11-2574090907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].astype('float64')
# /tmp/ipython-input-11-2574090907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
# /tmp/ipython-input-11-2574090907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].astype('float64')
# /tmp/ipython-input-11-2574090907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
# /tmp/ipython-input-11-2574090907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].astype('float64')
# /tmp/ipython-input-11-2574090907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
# /tmp/ipython-input-11-2574090907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].astype('float64')
# /tmp/ipython-input-11-2574090907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].replace(',', '', regex=True)
# /tmp/ipython-input-11-2574090907.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe[key] = filtered_dataframe[key].astype('float64')

# %%
filtered_dataframe
# Out:
#                             Date                     Line  In (Sum)  \
# 49     2022-08-31 19:00:00-05:00                   SILVER    3035.0
# 50     2022-08-31 19:00:00-05:00           SILVER EVENING     197.0
# 51     2022-08-31 19:00:00-05:00        SILVER LATE NIGHT      30.0
# 108    2022-09-01 19:00:00-05:00                   SILVER    2533.0
# 109    2022-09-01 19:00:00-05:00           SILVER EVENING     235.0
# ...                          ...                      ...       ...
# 15747  2023-09-28 19:00:00-05:00                   SILVER    2818.0
# 15748  2023-09-28 19:00:00-05:00           SILVER EVENING     448.0
# 15749  2023-09-28 19:00:00-05:00        SILVER LATE NIGHT     138.0
# 15771  2023-09-29 19:00:00-05:00  SILVER EVENING SATURDAY     688.0
# 15772  2023-09-29 19:00:00-05:00          SILVER SATURDAY    1590.0
#
#        Out (Sum)  Load (Avg.)  Load max  #APC-Trips
# 49        3035.0         12.6      75.0        93.0
# 50         197.0          4.2      18.0        15.0
# 51          30.0          1.0       9.0         9.0
# 108       2533.0         10.1      87.0        92.0
# 109        235.0          4.6      22.0        17.0
# ...          ...          ...       ...         ...
# 15747     2818.0         11.6      69.0        92.0
# 15748      448.0         10.1      45.0        15.0
# 15749      138.0          3.6      33.0        16.0
# 15771      688.0          4.7      38.0        58.0
# 15772     1590.0          9.9      85.0        60.0
#
# [931 rows x 7 columns]

# %%
filtered_dataframe = filtered_dataframe.set_index('Date')
filtered_dataframe.index
# Out:
# Index([2022-08-31 19:00:00-05:00, 2022-08-31 19:00:00-05:00,
#        2022-08-31 19:00:00-05:00, 2022-09-01 19:00:00-05:00,
#        2022-09-01 19:00:00-05:00, 2022-09-01 19:00:00-05:00,
#        2022-09-02 19:00:00-05:00, 2022-09-02 19:00:00-05:00,
#        2022-09-03 19:00:00-05:00, 2022-09-03 19:00:00-05:00,
#        ...
#        2023-09-26 19:00:00-05:00, 2023-09-26 19:00:00-05:00,
#        2023-09-27 19:00:00-05:00, 2023-09-27 19:00:00-05:00,
#        2023-09-27 19:00:00-05:00, 2023-09-28 19:00:00-05:00,
#        2023-09-28 19:00:00-05:00, 2023-09-28 19:00:00-05:00,
#        2023-09-29 19:00:00-05:00, 2023-09-29 19:00:00-05:00],
#       dtype='object', name='Date', length=931)

# %%
mask = filtered_dataframe['Line'] == 'SILVER'
silv = filtered_dataframe[mask]
silv
# Out:
#                              Line  In (Sum)  Out (Sum)  Load (Avg.)  Load max  \
# Date
# 2022-08-31 19:00:00-05:00  SILVER    3035.0     3035.0         12.6      75.0
# 2022-09-01 19:00:00-05:00  SILVER    2533.0     2533.0         10.1      87.0
# 2022-09-05 19:00:00-05:00  SILVER    2758.0     2758.0         10.9      95.0
# 2022-09-06 19:00:00-05:00  SILVER    3160.0     3160.0         12.9      76.0
# 2022-09-07 19:00:00-05:00  SILVER    2740.0     2740.0         10.7      66.0
# ...                           ...       ...        ...          ...       ...
# 2023-09-24 19:00:00-05:00  SILVER    3441.0     3441.0         14.3      81.0
# 2023-09-25 19:00:00-05:00  SILVER    2970.0     2970.0         11.7      79.0
# 2023-09-26 19:00:00-05:00  SILVER    3436.0     3436.0         13.8      73.0
# 2023-09-27 19:00:00-05:00  SILVER    3225.0     3225.0         13.0      78.0
# 2023-09-28 19:00:00-05:00  SILVER    2818.0     2818.0         11.6      69.0
#
#                            #APC-Trips
# Date
# 2022-08-31 19:00:00-05:00        93.0
# 2022-09-01 19:00:00-05:00        92.0
# 2022-09-05 19:00:00-05:00        97.0
# 2022-09-06 19:00:00-05:00        94.0
# 2022-09-07 19:00:00-05:00        93.0
# ...                               ...
# 2023-09-24 19:00:00-05:00        92.0
# 2023-09-25 19:00:00-05:00        93.0
# 2023-09-26 19:00:00-05:00        92.0
# 2023-09-27 19:00:00-05:00        94.0
# 2023-09-28 19:00:00-05:00        92.0
#
# [277 rows x 6 columns]

# %%
def plot_data(silver,y_var):
  y = silver[y_var]
  y = y.asfreq('D')
  y = y.fillna(y.mean())
  plt.figure(figsize=(20, 6))
  plt.plot(y, label='Observed Data', color='blue')
  plt.title('Load max for silver Line')
  plt.xlabel('Time')
  plt.ylabel(y_var)

# %%
def forecast(silver,y_var,step_var):
  y = silver[y_var]
  y = y.asfreq('D')
  y = y.fillna(y.mean())

  model = ExponentialSmoothing(y, seasonal='mul', seasonal_periods=160).fit()
  y_forecasted = model.forecast(steps=step_var)
  print(y_var)
  plt.figure(figsize=(20, 6))
  plt.plot(y, label='Observed', color='blue')
  plt.plot(y_forecasted, label='Forecast', color='red')
  plt.title(y_var+' Forecast for silver Line')
  plt.xlabel('Time')
  plt.ylabel(y_var)
  plt.legend()
  print(type(y_forecasted))
  print(y_forecasted)

  forecast_df = pd.DataFrame(y_forecasted, columns=['Forecasted Value'])

  # Resetting the index to turn the dates into a separate column
  forecast_df.reset_index(inplace=True)
  forecast_df.rename(columns={'index': 'Date'}, inplace=True)

# %%
plot_data(silv,columns_to_traverse[2])

# %%
steps = [256,256,256,256]
for j,step in zip(columns_to_traverse,steps):
  forecast(silv,j,step)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:903: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# In (Sum)
# <class 'pandas.core.series.Series'>
# 2023-09-29 19:00:00-05:00    3427.329907
# 2023-09-30 19:00:00-05:00    3604.757572
# 2023-10-01 19:00:00-05:00    4357.330717
# 2023-10-02 19:00:00-05:00    3891.253022
# 2023-10-03 19:00:00-05:00    3323.347357
#                                 ...
# 2024-06-06 19:00:00-05:00    4245.292671
# 2024-06-07 19:00:00-05:00    3863.625089
# 2024-06-08 19:00:00-05:00    3844.984422
# 2024-06-09 19:00:00-05:00    4050.571997
# 2024-06-10 19:00:00-05:00    3340.299902
# Freq: D, Length: 256, dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:903: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# Out (Sum)
# <class 'pandas.core.series.Series'>
# 2023-09-29 19:00:00-05:00    3427.329907
# 2023-09-30 19:00:00-05:00    3604.757572
# 2023-10-01 19:00:00-05:00    4357.330717
# 2023-10-02 19:00:00-05:00    3891.253022
# 2023-10-03 19:00:00-05:00    3323.347357
#                                 ...
# 2024-06-06 19:00:00-05:00    4245.292671
# 2024-06-07 19:00:00-05:00    3863.625089
# 2024-06-08 19:00:00-05:00    3844.984422
# 2024-06-09 19:00:00-05:00    4050.571997
# 2024-06-10 19:00:00-05:00    3340.299902
# Freq: D, Length: 256, dtype: float64
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:903: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/holtwinters/model.py:903: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# Load (Avg.)
# <class 'pandas.core.series.Series'>
# 2023-09-29 19:00:00-05:00    13.997462
# 2023-09-30 19:00:00-05:00    13.350047
# 2023-10-01 19:00:00-05:00    17.160984
# 2023-10-02 19:00:00-05:00    15.462564
# 2023-10-03 19:00:00-05:00    12.980375
#                                ...
# 2024-06-06 19:00:00-05:00    19.489403
# 2024-06-07 19:00:00-05:00    18.000963
# 2024-06-08 19:00:00-05:00    17.549310
# 2024-06-09 19:00:00-05:00    18.475900
# 2024-06-10 19:00:00-05:00    15.077931
# Freq: D, Length: 256, dtype: float64
# Load max
# <class 'pandas.core.series.Series'>
# 2023-09-29 19:00:00-05:00     68.543537
# 2023-09-30 19:00:00-05:00     81.262487
# 2023-10-01 19:00:00-05:00     75.864842
# 2023-10-02 19:00:00-05:00    110.643417
# 2023-10-03 19:00:00-05:00     59.758042
#                                 ...
# 2024-06-06 19:00:00-05:00     90.038808
# 2024-06-07 19:00:00-05:00     82.690834
# 2024-06-08 19:00:00-05:00    109.999347
# 2024-06-09 19:00:00-05:00     82.963396
# 2024-06-10 19:00:00-05:00     87.459049
# Freq: D, Length: 256, dtype: float64
